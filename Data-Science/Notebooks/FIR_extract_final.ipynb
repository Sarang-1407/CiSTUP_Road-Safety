# %%
# !pip install pdfplumber
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: pdfplumber in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (0.11.4)
# Requirement already satisfied: pdfminer.six==20231228 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from pdfplumber) (20231228)
# Requirement already satisfied: Pillow>=9.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from pdfplumber) (10.4.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from pdfplumber) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (3.1.0)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (44.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pdfplumber
import re
from dataclasses import dataclass
from typing import Optional, List, Dict, Any
from datetime import datetime

@dataclass
class PropertyDetails:
    """Data class for stolen/involved property information"""
    sl_no: int
    property_type: Optional[str] = None
    item_description: Dict[str, Any] = None  # For structured item details
    estimated_value: Optional[float] = None

@dataclass
class VictimDetails:
    """Data class for victim information"""
    sl_no: int
    name: Optional[str] = None
    address: Optional[str] = None
    injury_type: Optional[str] = None
    sex: Optional[str] = None
    age: Optional[int] = None
    occupation: Optional[str] = None

@dataclass
class FIRData:
    """Data class to store extracted FIR information"""
    district: Optional[str] = None
    circle_subdivision: Optional[str] = None
    police_station: Optional[str] = None
    crime_no: Optional[str] = None
    fir_date: Optional[datetime] = None
    act_section: Optional[str] = None
    offense_date: Optional[datetime] = None
    offense_time_from: Optional[str] = None
    offense_time_to: Optional[str] = None
    location: Optional[str] = None
    distance_ps: Optional[str] = None
    complainant_name: Optional[str] = None
    complainant_age: Optional[int] = None
    complainant_religion: Optional[str] = None
    complainant_caste: Optional[str] = None
    complainant_occupation: Optional[str] = None
    phone_number: Optional[str] = None
    nationality: Optional[str] = None
    sex: Optional[str] = None
    complainant_address: Optional[str] = None
    victim_details: List[VictimDetails] = None
    property_details: List[PropertyDetails] = None
    total_property_value: Optional[float] = None

    def __post_init__(self):
        if self.victim_details is None:
            self.victim_details = []
        if self.property_details is None:
            self.property_details = []

    def print_details(self):
        """Print all FIR details in a formatted manner"""
        print("\n=== FIR Details ===")
        print(f"District: {self.district}")
        print(f"Circle/Sub-Division: {self.circle_subdivision}")
        print(f"Police Station: {self.police_station}")
        print(f"Crime Number: {self.crime_no}")
        print(f"FIR Date: {self.fir_date.strftime('%d/%m/%Y') if self.fir_date else None}")
        print(f"Act & Section: {self.act_section}")
        
        print("\nOffense Details:")
        print(f"Date: {self.offense_date.strftime('%d/%m/%Y') if self.offense_date else None}")
        print(f"Time: {self.offense_time_from} to {self.offense_time_to}")
        print(f"Location: {self.location}")
        print(f"Distance from Police Station: {self.distance_ps}")

        print("\nComplainant Details:")
        print(f"Name: {self.complainant_name}")
        print(f"Age: {self.complainant_age}")
        print(f"Religion: {self.complainant_religion}")
        print(f"Caste: {self.complainant_caste}")
        print(f"Occupation: {self.complainant_occupation}")
        print(f"Phone: {self.phone_number}")
        print(f"Nationality: {self.nationality}")
        print(f"Sex: {self.sex}")
        print(f"Address: {self.complainant_address}")
        
        print("\nProperty Details:")
        for prop in self.property_details:
            print(f"- Type: {prop.property_type}")
            if prop.item_description:
                print("  Item Description:")
                for key, value in prop.item_description.items():
                    print(f"    {key}: {value}")
            print(f"  Estimated Value: {f'Rs. {prop.estimated_value:,.2f}' if prop.estimated_value else None}")
        print(f"Total Property Value: {f'Rs. {self.total_property_value:,.2f}' if self.total_property_value else None}")
        print("==================\n")

def safe_search(pattern: str, text: str, group_num: int = 1) -> Optional[str]:
    """Helper function to safely perform regex search and return the matched group or None."""
    try:
        match = re.search(pattern, text)
        return match.group(group_num).strip() if match else None
    except (AttributeError, IndexError):
        return None

def safe_parse_date(date_str: Optional[str], format_str: str = "%d/%m/%Y") -> Optional[datetime]:
    """Safely parse date string to datetime object."""
    if not date_str:
        return None
    try:
        return datetime.strptime(date_str, format_str)
    except ValueError:
        return None

def safe_parse_int(value: Optional[str]) -> Optional[int]:
    """Safely parse string to integer."""
    if not value:
        return None
    try:
        return int(re.sub(r'[^\d]', '', value))
    except ValueError:
        return None

def safe_parse_float(amount_str: Optional[str]) -> Optional[float]:
    """Safely parse string to float, handling commas in numbers."""
    if not amount_str:
        return None
    try:
        return float(amount_str.replace(',', ''))
    except ValueError:
        return None

def extract_fir_data(pdf_path: str) -> FIRData:
    """Extract relevant information from FIR PDF document with error handling"""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            text = " ".join([page.extract_text() for page in pdf.pages])
            
            # Basic FIR details
            district = safe_search(r"District\s*:\s*([^:\n]+?)(?=\s+Circle/Sub Division|$)", text)
            circle = safe_search(r"Circle/Sub Division\s*:\s*([^:\n]+?)(?=\s+PS|$)", text)
            ps = safe_search(r"PS\s*:\s*([^:\n]+?)(?=\s*$|\s*\n)", text)
            crime_no = safe_search(r"Crime No\s*:\s*([^:\n]+?)(?=\s+FIR Date|$)", text)
            
            # Dates and times
            fir_date_str = safe_search(r"FIR Date\s*:\s*(\d{2}/\d{1,2}/\d{4})", text)
            fir_date = safe_parse_date(fir_date_str)
            
            offense_date_str = safe_search(r"From Date\s*:\s*(\d{2}/\d{2}/\d{4})", text)
            offense_date = safe_parse_date(offense_date_str)
            
            time_from = safe_search(r"From Time\s*:\s*(\d{2}:\d{2}:\d{2})", text)
            time_to = safe_search(r"To Time\s*:\s*(\d{2}:\d{2}:\d{2})", text)
            
            # Location and distance
            location = re.search(r"Place of occurence with full address\s*(.*?)(?=\(b\))", text, re.DOTALL).group(1).strip()
            distance_match = re.search(r"(?:(Tow(?:ards|ords)\s+\w+)\s*([\d\.]+)\s*(K\s*M|KM|Km|KMs|Meters|M)?)|(?:([\d\.]+)\s*(K\s*M|KM|Km|KMs|Meters|M)?\s*(Tow(?:ards|ords)\s+\w+))", text, re.IGNORECASE)
            
            distance_ps = None
            if distance_match:
                direction = (distance_match.group(1) or distance_match.group(6) or "").strip()
                distance_value = (distance_match.group(2) or distance_match.group(4) or "").strip()
                distance_unit = (distance_match.group(3) or distance_match.group(5) or "").strip()
                if direction and distance_value:
                    distance_ps = f"{direction}, {distance_value} {distance_unit}".strip()
            
            # Complainant details
            complainant_name = safe_search(r"Name\s*:\s*([^:\n]+?)(?=\s+Father)", text)
            complainant_age_str = safe_search(r"Age\s*:\s*(\d+)", text)
            complainant_age = safe_parse_int(complainant_age_str)
            complainant_religion = safe_search(r"Religion\s*:\s*([^:\n]+?)(?=\s*(?:\([e-z]\)|$))", text)
            complainant_caste = safe_search(r"Caste\s*:\s*([^:\n]+?)(?=\s*(?:\([f-z]\)|$))", text)
            complainant_occupation = safe_search(r"Occupation\s*:\s*([^\n]*)", text)
            phone_number = safe_search(r"Phone No\.\s*:\s*(\d+)", text)
            nationality = safe_search(r"Nationality\s*:\s*([^:\n]+?)(?=\s|$)", text)
            sex = safe_search(r"Sex:\s*([^:\n]+?)(?=\s|$)", text)
            
            # Address extraction
            address_match = safe_search(r"\(k\)\s*Address\s*:\s*([\s\S]*?)(?=\([m-z]\)|Whether complainant|$)", text)
            complainant_address = None
            if address_match:
                address_text = address_match
                sex_pattern = r"\(l\)\s*Sex:\s*[A-Za-z]+\s*"
                address_text = re.sub(sex_pattern, "", address_text)
                complainant_address = " ".join(line.strip() for line in address_text.split('\n') if line.strip())
            
            # Property details
            property_details = []
            if "Automobile" in text:
                item_desc = {
                    "reg_no": safe_search(r"Reg No:?\s*([A-Za-z0-9]+)(?=\s*(?:\d+|Make|$))", text),
                    "make": safe_search(r"Make:?\s*([^\n]+?)(?=\s*Model|$)", text),
                    "model": safe_search(r"Model:?\s*(\d+)", text),
                    "engine_no": safe_search(r"Engine No:?\s*([^\n]+?)(?=\s*Chassis|$)", text),
                    "chassis_no": safe_search(r"Chassis No:?\s*([^\n]+?)(?=\n|$)", text)
                }
                
                value_str = safe_search(r"Estimated Value[^:]*:?\s*(?:Rs\.?)?\s*(\d+,?\d*)", text)
                estimated_value = safe_parse_float(value_str)
                
                property_details.append(PropertyDetails(1, "Automobile", item_desc, estimated_value))
            
            # Total value
            total_value_str = safe_search(r"Total Value[^:]*:?\s*(?:Rs\.?)?\s*(\d+,?\d*)", text)
            total_property_value = safe_parse_float(total_value_str)
            
            act_section = safe_search(r"Act & Section\s*:\s*([^:\n]+)", text)
            
            return FIRData(
                district=district,
                circle_subdivision=circle,
                police_station=ps,
                crime_no=crime_no,
                fir_date=fir_date,
                act_section=act_section,
                offense_date=offense_date,
                offense_time_from=time_from,
                offense_time_to=time_to,
                location=location,
                distance_ps=distance_ps,
                complainant_name=complainant_name,
                complainant_age=complainant_age,
                complainant_religion=complainant_religion,
                complainant_caste=complainant_caste,
                complainant_occupation=complainant_occupation,
                phone_number=phone_number,
                nationality=nationality,
                sex=sex,
                complainant_address=complainant_address,
                victim_details=[],
                property_details=property_details,
                total_property_value=total_property_value
            )
            
    except Exception as e:
        print(f"Error processing PDF: {str(e)}")
        return FIRData()  # Return empty FIRData object if processing fails

if __name__ == "__main__":
    # Process single FIR
    fir = extract_fir_data("E:/sample FIRs/output/output_1761_fir_0340.pdf")
    fir.print_details()
# Out:
# === FIR Details ===
# District: Bengaluru City
# Circle/Sub-Division: Central Traffic Sub Division
# Police Station: Ashoknagar Traffic PS
# Crime Number: 0340/2023
# FIR Date: 29/10/2023
# Act & Section: IPC 1860 (U/s-279); INDIAN MOTOR VEHICLES ACT, 1988
#
# Offense Details:
# Date: 28/10/2023
# Time: 20:00:00 to 20:05:00
# Location: NEAR APERA JUNCTION, Residency Road, Ashoknagar,Bengaluru City ,
# Karnataka, 560025
# Distance from Police Station: towards west, 1
#
# Complainant Details:
# Name: Arathi
# Age: 51
# Religion: Hindu
# Caste: CHUNAR
# Occupation: Housewife
# Phone: 9980589350
# Nationality: India
# Sex: Female
# Address: A-404, Royal Residency, Bruntow Road,Opp M.G Road , Bengaluru City , Karnataka-56002 5
#
# Property Details:
# - Type: Automobile
#   Item Description:
#     reg_no: KA05AF1820
#     make: AUTO RICKSHAW
#     model: None
#     engine_no: -
#     chassis_no: - 2 Automobile Reg No: KA04MZ9653 200000
#   Estimated Value: Rs. 1.00
# Total Property Value: Rs. 250,000.00
# ==================

# %%
import pdfplumber
import re
from dataclasses import dataclass
from typing import Optional, List, Dict, Any
from datetime import datetime
import pandas as pd
import os
from pathlib import Path


def create_flat_dict(fir: FIRData) -> Dict[str, Any]:
    """Convert FIR data to a flat dictionary suitable for CSV export"""
    flat_dict = {
        'district': fir.district,
        'circle_subdivision': fir.circle_subdivision,
        'police_station': fir.police_station,
        'crime_no': fir.crime_no,
        'fir_date': fir.fir_date.strftime('%d/%m/%Y') if fir.fir_date else None,
        'act_section': fir.act_section,
        'offense_date': fir.offense_date.strftime('%d/%m/%Y') if fir.offense_date else None,
        'offense_time_from': fir.offense_time_from,
        'offense_time_to': fir.offense_time_to,
        'location': fir.location,
        'distance_ps': fir.distance_ps,
        'complainant_name': fir.complainant_name,
        'complainant_age': fir.complainant_age,
        'complainant_religion': fir.complainant_religion,
        'complainant_caste': fir.complainant_caste,
        'complainant_occupation': fir.complainant_occupation,
        'phone_number': fir.phone_number,
        'nationality': fir.nationality,
        'sex': fir.sex,
        'complainant_address': fir.complainant_address,
        'total_property_value': fir.total_property_value
    }

    # Add property details
    if fir.property_details:
        for i, prop in enumerate(fir.property_details, 1):
            prefix = f'property_{i}_'
            flat_dict[f'{prefix}type'] = prop.property_type
            flat_dict[f'{prefix}value'] = prop.estimated_value
            if prop.item_description:
                for key, value in prop.item_description.items():
                    flat_dict[f'{prefix}{key}'] = value

    if fir.victim_details:
        for i, victim in enumerate(fir.victim_details, 1):
            prefix = f'victim_{i}_'
            flat_dict[f'{prefix}name'] = victim.name
            flat_dict[f'{prefix}address'] = victim.address
            flat_dict[f'{prefix}injury_type'] = victim.injury_type
            flat_dict[f'{prefix}sex'] = victim.sex
            flat_dict[f'{prefix}age'] = victim.age
            flat_dict[f'{prefix}occupation'] = victim.occupation

    return flat_dict

def process_fir_files(input_folder: str, output_file: str):
    """
    Process all FIR PDF files in a folder and create a CSV dataset
    
    Args:
        input_folder (str): Path to folder containing FIR PDFs
        output_file (str): Path where CSV file should be saved
    """
    pdf_files = list(Path(input_folder).glob("*.pdf"))
    
    if not pdf_files:
        print(f"No PDF files found in {input_folder}")
        return
    
    print(f"Found {len(pdf_files)} PDF files to process")
    

    all_data = []
    failed_files = []
    
    for i, pdf_file in enumerate(pdf_files, 1):
        print(f"Processing file {i}/{len(pdf_files)}: {pdf_file.name}")
        try:
            fir = extract_fir_data(str(pdf_file))
            flat_data = create_flat_dict(fir)
            flat_data['file_name'] = pdf_file.name 
            all_data.append(flat_data)
        except Exception as e:
            print(f"Failed to process {pdf_file.name}: {str(e)}")
            failed_files.append(pdf_file.name)
    
    if not all_data:
        print("No data was successfully extracted")
        return

    df = pd.DataFrame(all_data)
    
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
    
 
    df.to_csv(output_file, index=False, encoding='utf-8')
    

    print("\nProcessing Summary:")
    print(f"Total files processed: {len(pdf_files)}")
    print(f"Successfully processed: {len(all_data)}")
    print(f"Failed to process: {len(failed_files)}")
    
    if failed_files:
        print("\nFailed files:")
        for file in failed_files:
            print(f"- {file}")
    

    print("\nDataset Statistics:")
    print(f"Total rows: {len(df)}")
    print(f"Total columns: {len(df.columns)}")
    
    key_columns = ['district', 'police_station', 'crime_no']
    print("\nUnique values in key columns:")
    for col in key_columns:
        if col in df.columns:
            unique_count = df[col].nunique()
            print(f"{col}: {unique_count} unique values")

if __name__ == "__main__":
    input_folder = "E:/sample FIRs/output"  
    output_file = "E:/sample FIRs/output/fir_dataset1.csv"  
    
    process_fir_files(input_folder, output_file)
# Out:
# Found 809 PDF files to process
# Processing file 1/809: output_1367_fir_0153.pdf
# Processing file 2/809: output_1761_fir_0022.pdf
# Processing file 3/809: output_1761_fir_0232.pdf
# Processing file 4/809: output_1761_fir_0334.pdf
# Processing file 5/809: output_1761_fir_0335.pdf
# Processing file 6/809: output_1761_fir_0340.pdf
# Processing file 7/809: output_1761_fir_0351.pdf
# Processing file 8/809: output_1761_fir_0354.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 9/809: output_1761_fir_0358.pdf
# Processing file 10/809: output_1761_fir_0359.pdf
# Processing file 11/809: output_1761_fir_0361.pdf
# Processing file 12/809: output_1763_fir_0067.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 13/809: output_1763_fir_0073.pdf
# Processing file 14/809: output_1763_fir_0178.pdf
# Processing file 15/809: output_1763_fir_0329.pdf
# Processing file 16/809: output_1763_fir_0331.pdf
# Processing file 17/809: output_1763_fir_0341.pdf
# Processing file 18/809: output_1763_fir_0346.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 19/809: output_1763_fir_0352.pdf
# Processing file 20/809: output_1763_fir_0353.pdf
# Processing file 21/809: output_1764_fir_0008.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 22/809: output_1764_fir_0093.pdf
# Processing file 23/809: output_1764_fir_0120.pdf
# Processing file 24/809: output_1764_fir_0143.pdf
# Processing file 25/809: output_1764_fir_0152.pdf
# Processing file 26/809: output_1764_fir_0153.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 27/809: output_1764_fir_0168.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 28/809: output_1764_fir_0170.pdf
# Processing file 29/809: output_1764_fir_0187.pdf
# Processing file 30/809: output_1764_fir_0189.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 31/809: output_1764_fir_0191.pdf
# Processing file 32/809: output_1764_fir_0192.pdf
# Processing file 33/809: output_1764_fir_0193.pdf
# Processing file 34/809: output_1764_fir_0195.pdf
# Processing file 35/809: output_1764_fir_0197.pdf
# Processing file 36/809: output_1764_fir_0198.pdf
# Processing file 37/809: output_1764_fir_0199.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 38/809: output_1764_fir_0202.pdf
# Processing file 39/809: output_1764_fir_0204.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 40/809: output_1764_fir_0206.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 41/809: output_1765_fir_0017.pdf
# Processing file 42/809: output_1765_fir_0026.pdf
# Processing file 43/809: output_1765_fir_0131.pdf
# Processing file 44/809: output_1765_fir_0140.pdf
# Processing file 45/809: output_1765_fir_0148.pdf
# Processing file 46/809: output_1765_fir_0162.pdf
# Processing file 47/809: output_1765_fir_0181.pdf
# Processing file 48/809: output_1765_fir_0197.pdf
# Processing file 49/809: output_1765_fir_0210.pdf
# Processing file 50/809: output_1765_fir_0218.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 51/809: output_1765_fir_0222.pdf
# Processing file 52/809: output_1765_fir_0225.pdf
# Processing file 53/809: output_1766_fir_0024.pdf
# Processing file 54/809: output_1766_fir_0094.pdf
# Processing file 55/809: output_1766_fir_0126.pdf
# Processing file 56/809: output_1766_fir_0131.pdf
# Processing file 57/809: output_1768_fir_0026.pdf
# Processing file 58/809: output_1768_fir_0036.pdf
# Processing file 59/809: output_1768_fir_0056.pdf
# Processing file 60/809: output_1768_fir_0068.pdf
# Processing file 61/809: output_1768_fir_0077.pdf
# Processing file 62/809: output_1768_fir_0089.pdf
# Processing file 63/809: output_1770_fir_0105.pdf
# Processing file 64/809: output_1770_fir_0113.pdf
# Processing file 65/809: output_1770_fir_0142.pdf
# Processing file 66/809: output_1770_fir_0194.pdf
# Processing file 67/809: output_1770_fir_0214.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 68/809: output_1770_fir_0225.pdf
# Processing file 69/809: output_1770_fir_0233.pdf
# Processing file 70/809: output_1770_fir_0234.pdf
# Processing file 71/809: output_1770_fir_0243.pdf
# Processing file 72/809: output_1770_fir_0257.pdf
# Processing file 73/809: output_1770_fir_0278.pdf
# Processing file 74/809: output_1771_fir_0008.pdf
# Processing file 75/809: output_1771_fir_0009.pdf
# Processing file 76/809: output_1771_fir_0052.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 77/809: output_1771_fir_0067.pdf
# Processing file 78/809: output_1771_fir_0090.pdf
# Processing file 79/809: output_1771_fir_0108.pdf
# Processing file 80/809: output_1771_fir_0110.pdf
# Processing file 81/809: output_1771_fir_0134.pdf
# Processing file 82/809: output_1771_fir_0136.pdf
# Processing file 83/809: output_1773_fir_0175.pdf
# Processing file 84/809: output_1773_fir_0242.pdf
# Processing file 85/809: output_1773_fir_0243.pdf
# Processing file 86/809: output_1773_fir_0247.pdf
# Processing file 87/809: output_1773_fir_0254.pdf
# Processing file 88/809: output_1773_fir_0262.pdf
# Processing file 89/809: output_1773_fir_0269.pdf
# Processing file 90/809: output_1773_fir_0284.pdf
# Processing file 91/809: output_1773_fir_0292.pdf
# Processing file 92/809: output_1773_fir_0293.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 93/809: output_1773_fir_0295.pdf
# Processing file 94/809: output_1773_fir_0297.pdf
# Processing file 95/809: output_1773_fir_0299.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 96/809: output_1773_fir_0302.pdf
# Processing file 97/809: output_1774_fir_0008.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 98/809: output_1774_fir_0025.pdf
# Processing file 99/809: output_1774_fir_0029.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 100/809: output_1774_fir_0034.pdf
# Processing file 101/809: output_1774_fir_0042.pdf
# Processing file 102/809: output_1774_fir_0044.pdf
# Processing file 103/809: output_1774_fir_0064.pdf
# Processing file 104/809: output_1774_fir_0067.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 105/809: output_1774_fir_0068.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 106/809: output_1774_fir_0074.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 107/809: output_1774_fir_0075.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 108/809: output_1774_fir_0077.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 109/809: output_1774_fir_0086.pdf
# Processing file 110/809: output_1774_fir_0121.pdf
# Processing file 111/809: output_1774_fir_0134.pdf
# Processing file 112/809: output_1774_fir_0135.pdf
# Processing file 113/809: output_1774_fir_0147.pdf
# Processing file 114/809: output_1774_fir_0176.pdf
# Processing file 115/809: output_1774_fir_0181.pdf
# Processing file 116/809: output_1774_fir_0210.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 117/809: output_1774_fir_0219.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 118/809: output_1774_fir_0253.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 119/809: output_1774_fir_0258.pdf
# Processing file 120/809: output_1774_fir_0265.pdf
# Processing file 121/809: output_1774_fir_0270.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 122/809: output_1774_fir_0276.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 123/809: output_1774_fir_0287.pdf
# Processing file 124/809: output_1774_fir_0288.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 125/809: output_1774_fir_0300.pdf
# Processing file 126/809: output_1774_fir_0310.pdf
# Processing file 127/809: output_1774_fir_0312.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 128/809: output_1774_fir_0317.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 129/809: output_1774_fir_0335.pdf
# Processing file 130/809: output_1774_fir_0343.pdf
# Processing file 131/809: output_1774_fir_0344.pdf
# Processing file 132/809: output_1774_fir_0354.pdf
# Processing file 133/809: output_1774_fir_0358.pdf
# Processing file 134/809: output_1774_fir_0361.pdf
# Processing file 135/809: output_1774_fir_0362.pdf
# Processing file 136/809: output_1774_fir_0368.pdf
# Processing file 137/809: output_1774_fir_0369.pdf
# Processing file 138/809: output_1774_fir_0370.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 139/809: output_1774_fir_0373.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 140/809: output_1774_fir_0375.pdf
# Processing file 141/809: output_1774_fir_0379.pdf
# Processing file 142/809: output_1774_fir_0384.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 143/809: output_1774_fir_0386.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 144/809: output_1774_fir_0389.pdf
# Processing file 145/809: output_1774_fir_0390.pdf
# Processing file 146/809: output_1774_fir_0393.pdf
# Processing file 147/809: output_1774_fir_0400.pdf
# Processing file 148/809: output_1774_fir_0401.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 149/809: output_1774_fir_0402.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 150/809: output_1774_fir_0403.pdf
# Processing file 151/809: output_1774_fir_0404.pdf
# Processing file 152/809: output_1774_fir_0407.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 153/809: output_1774_fir_0415.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 154/809: output_1774_fir_0417.pdf
# Processing file 155/809: output_1774_fir_0418.pdf
# Processing file 156/809: output_1774_fir_0419.pdf
# Processing file 157/809: output_1774_fir_0420.pdf
# Processing file 158/809: output_1774_fir_0421.pdf
# Processing file 159/809: output_1774_fir_0422.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 160/809: output_1774_fir_0423.pdf
# Processing file 161/809: output_1774_fir_0424.pdf
# Processing file 162/809: output_1775_fir_0014.pdf
# Processing file 163/809: output_1775_fir_0100.pdf
# Processing file 164/809: output_1775_fir_0124.pdf
# Processing file 165/809: output_1775_fir_0125.pdf
# Processing file 166/809: output_1775_fir_0157.pdf
# Processing file 167/809: output_1775_fir_0165.pdf
# Processing file 168/809: output_1775_fir_0178.pdf
# Processing file 169/809: output_1775_fir_0179.pdf
# Processing file 170/809: output_1775_fir_0180.pdf
# Processing file 171/809: output_1775_fir_0181.pdf
# Processing file 172/809: output_1776_fir_0016.pdf
# Processing file 173/809: output_1776_fir_0035.pdf
# Processing file 174/809: output_1776_fir_0044.pdf
# Processing file 175/809: output_1776_fir_0136.pdf
# Processing file 176/809: output_1776_fir_0272.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 177/809: output_1776_fir_0274.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 178/809: output_1776_fir_0284.pdf
# Processing file 179/809: output_1776_fir_0287.pdf
# Processing file 180/809: output_1776_fir_0288.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 181/809: output_1776_fir_0289.pdf
# Processing file 182/809: output_1776_fir_0290.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 183/809: output_1776_fir_0292.pdf
# Processing file 184/809: output_1776_fir_0293.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 185/809: output_1777_fir_0003.pdf
# Processing file 186/809: output_1777_fir_0061.pdf
# Processing file 187/809: output_1777_fir_0062.pdf
# Processing file 188/809: output_1777_fir_0083.pdf
# Processing file 189/809: output_1777_fir_0102.pdf
# Processing file 190/809: output_1777_fir_0142.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 191/809: output_1777_fir_0171.pdf
# Processing file 192/809: output_1777_fir_0175.pdf
# Processing file 193/809: output_1777_fir_0201.pdf
# Processing file 194/809: output_1777_fir_0202.pdf
# Processing file 195/809: output_1777_fir_0262.pdf
# Processing file 196/809: output_1778_fir_0014.pdf
# Processing file 197/809: output_1778_fir_0034.pdf
# Processing file 198/809: output_1778_fir_0037.pdf
# Processing file 199/809: output_1778_fir_0079.pdf
# Processing file 200/809: output_1778_fir_0085.pdf
# Processing file 201/809: output_1778_fir_0105.pdf
# Processing file 202/809: output_1778_fir_0111.pdf
# Processing file 203/809: output_1778_fir_0165.pdf
# Processing file 204/809: output_1778_fir_0212.pdf
# Processing file 205/809: output_1778_fir_0226.pdf
# Processing file 206/809: output_1778_fir_0296.pdf
# Processing file 207/809: output_1778_fir_0300.pdf
# Processing file 208/809: output_1778_fir_0319.pdf
# Processing file 209/809: output_1778_fir_0344.pdf
# Processing file 210/809: output_1778_fir_0359.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 211/809: output_1778_fir_0368.pdf
# Processing file 212/809: output_1778_fir_0387.pdf
# Processing file 213/809: output_1778_fir_0400.pdf
# Processing file 214/809: output_1778_fir_0426.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 215/809: output_1778_fir_0427.pdf
# Processing file 216/809: output_1778_fir_0428.pdf
# Processing file 217/809: output_1778_fir_0429.pdf
# Processing file 218/809: output_1778_fir_0432.pdf
# Processing file 219/809: output_1778_fir_0435.pdf
# Processing file 220/809: output_1778_fir_0436.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 221/809: output_1778_fir_0437.pdf
# Processing file 222/809: output_1778_fir_0438.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 223/809: output_1780_fir_0088.pdf
# Processing file 224/809: output_1780_fir_0108.pdf
# Processing file 225/809: output_1780_fir_0110.pdf
# Processing file 226/809: output_1780_fir_0113.pdf
# Processing file 227/809: output_1780_fir_0120.pdf
# Processing file 228/809: output_1780_fir_0149.pdf
# Processing file 229/809: output_1780_fir_0161.pdf
# Processing file 230/809: output_1780_fir_0164.pdf
# Processing file 231/809: output_1780_fir_0166.pdf
# Processing file 232/809: output_1780_fir_0168.pdf
# Processing file 233/809: output_1781_fir_0202.pdf
# Processing file 234/809: output_1781_fir_0323.pdf
# Processing file 235/809: output_1781_fir_0429.pdf
# Processing file 236/809: output_1781_fir_0484.pdf
# Processing file 237/809: output_1781_fir_0509.pdf
# Processing file 238/809: output_1781_fir_0520.pdf
# Processing file 239/809: output_1781_fir_0522.pdf
# Processing file 240/809: output_1782_fir_0227.pdf
# Processing file 241/809: output_1782_fir_0358.pdf
# Processing file 242/809: output_1782_fir_0365.pdf
# Processing file 243/809: output_1782_fir_0366.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 244/809: output_1782_fir_0373.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 245/809: output_1782_fir_0375.pdf
# Processing file 246/809: output_1782_fir_0392.pdf
# Processing file 247/809: output_1782_fir_0401.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 248/809: output_1782_fir_0409.pdf
# Processing file 249/809: output_1782_fir_0410.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 250/809: output_1782_fir_0416.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 251/809: output_1784_fir_0156.pdf
# Processing file 252/809: output_1784_fir_0157.pdf
# Processing file 253/809: output_1784_fir_0175.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 254/809: output_1784_fir_0234.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 255/809: output_1784_fir_0246.pdf
# Processing file 256/809: output_1784_fir_0254.pdf
# Processing file 257/809: output_1784_fir_0259.pdf
# Processing file 258/809: output_1784_fir_0269.pdf
# Processing file 259/809: output_1784_fir_0288.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 260/809: output_1784_fir_0294.pdf
# Processing file 261/809: output_1784_fir_0298.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 262/809: output_1784_fir_0301.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 263/809: output_1784_fir_0302.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 264/809: output_1784_fir_0308.pdf
# Processing file 265/809: output_1784_fir_0309.pdf
# Processing file 266/809: output_1784_fir_0310.pdf
# Processing file 267/809: output_1784_fir_0311.pdf
# Processing file 268/809: output_1784_fir_0312.pdf
# Processing file 269/809: output_1784_fir_0313.pdf
# Processing file 270/809: output_1784_fir_0314.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 271/809: output_1785_fir_0012.pdf
# Processing file 272/809: output_1785_fir_0184.pdf
# Processing file 273/809: output_1785_fir_0194.pdf
# Processing file 274/809: output_1785_fir_0195.pdf
# Processing file 275/809: output_1785_fir_0196.pdf
# Processing file 276/809: output_1785_fir_0198.pdf
# Processing file 277/809: output_1785_fir_0199.pdf
# Processing file 278/809: output_1786_fir_0011.pdf
# Processing file 279/809: output_1786_fir_0211.pdf
# Processing file 280/809: output_1786_fir_0311.pdf
# Processing file 281/809: output_1786_fir_0364.pdf
# Processing file 282/809: output_1786_fir_0371.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 283/809: output_1786_fir_0372.pdf
# Processing file 284/809: output_1786_fir_0373.pdf
# Processing file 285/809: output_1786_fir_0374.pdf
# Processing file 286/809: output_1786_fir_0376.pdf
# Processing file 287/809: output_1786_fir_0377.pdf
# Processing file 288/809: output_1786_fir_0379.pdf
# Processing file 289/809: output_1786_fir_0380.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 290/809: output_1786_fir_0381.pdf
# Processing file 291/809: output_1786_fir_0382.pdf
# Processing file 292/809: output_1787_fir_0003.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 293/809: output_1787_fir_0046.pdf
# Processing file 294/809: output_1787_fir_0122.pdf
# Processing file 295/809: output_1787_fir_0175.pdf
# Processing file 296/809: output_1787_fir_0190.pdf
# Processing file 297/809: output_1787_fir_0227.pdf
# Processing file 298/809: output_1787_fir_0229.pdf
# Processing file 299/809: output_1787_fir_0315.pdf
# Processing file 300/809: output_1787_fir_0319.pdf
# Processing file 301/809: output_1787_fir_0320.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 302/809: output_1787_fir_0321.pdf
# Processing file 303/809: output_1787_fir_0352.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 304/809: output_1787_fir_0354.pdf
# Processing file 305/809: output_1787_fir_0361.pdf
# Processing file 306/809: output_1787_fir_0372.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 307/809: output_1787_fir_0378.pdf
# Processing file 308/809: output_1787_fir_0380.pdf
# Processing file 309/809: output_1787_fir_0384.pdf
# Processing file 310/809: output_1787_fir_0390.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 311/809: output_1787_fir_0411.pdf
# Processing file 312/809: output_1787_fir_0419.pdf
# Processing file 313/809: output_1787_fir_0422.pdf
# Processing file 314/809: output_1787_fir_0424.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 315/809: output_1787_fir_0425.pdf
# Processing file 316/809: output_1787_fir_0426.pdf
# Processing file 317/809: output_1787_fir_0427.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 318/809: output_1787_fir_0428.pdf
# Processing file 319/809: output_1787_fir_0429.pdf
# Processing file 320/809: output_1788_fir_0139.pdf
# Processing file 321/809: output_1788_fir_0151.pdf
# Processing file 322/809: output_1788_fir_0222.pdf
# Processing file 323/809: output_1788_fir_0223.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 324/809: output_1788_fir_0233.pdf
# Processing file 325/809: output_1788_fir_0255.pdf
# Processing file 326/809: output_1789_fir_0023.pdf
# Processing file 327/809: output_1789_fir_0216.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 328/809: output_1789_fir_0219.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 329/809: output_1789_fir_0313.pdf
# Processing file 330/809: output_1789_fir_0316.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 331/809: output_1789_fir_0317.pdf
# Processing file 332/809: output_1789_fir_0323.pdf
# Processing file 333/809: output_1789_fir_0338.pdf
# Processing file 334/809: output_1789_fir_0339.pdf
# Processing file 335/809: output_1789_fir_0341.pdf
# Processing file 336/809: output_1792_fir_0047.pdf
# Processing file 337/809: output_1792_fir_0052.pdf
# Processing file 338/809: output_1792_fir_0059.pdf
# Processing file 339/809: output_1792_fir_0075.pdf
# Processing file 340/809: output_1792_fir_0082.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 341/809: output_1792_fir_0109.pdf
# Processing file 342/809: output_1792_fir_0114.pdf
# Processing file 343/809: output_1792_fir_0129.pdf
# Processing file 344/809: output_1792_fir_0157.pdf
# Processing file 345/809: output_1792_fir_0158.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 346/809: output_1792_fir_0169.pdf
# Processing file 347/809: output_1792_fir_0172.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 348/809: output_1792_fir_0174.pdf
# Processing file 349/809: output_1792_fir_0175.pdf
# Processing file 350/809: output_1792_fir_0176.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 351/809: output_1792_fir_0177.pdf
# Processing file 352/809: output_1792_fir_0178.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 353/809: output_1792_fir_0180.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 354/809: output_1792_fir_0182.pdf
# Processing file 355/809: output_1792_fir_0187.pdf
# Processing file 356/809: output_1792_fir_0191.pdf
# Processing file 357/809: output_1792_fir_0192.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 358/809: output_1792_fir_0193.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 359/809: output_1792_fir_0194.pdf
# Processing file 360/809: output_1793_fir_0020.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 361/809: output_1793_fir_0097.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 362/809: output_1793_fir_0120.pdf
# Processing file 363/809: output_1793_fir_0127.pdf
# Processing file 364/809: output_1793_fir_0133.pdf
# Processing file 365/809: output_1793_fir_0140.pdf
# Processing file 366/809: output_1793_fir_0209.pdf
# Processing file 367/809: output_1793_fir_0212.pdf
# Processing file 368/809: output_1793_fir_0240.pdf
# Processing file 369/809: output_1793_fir_0246.pdf
# Processing file 370/809: output_1793_fir_0265.pdf
# Processing file 371/809: output_1793_fir_0269.pdf
# Processing file 372/809: output_1793_fir_0271.pdf
# Processing file 373/809: output_1793_fir_0274.pdf
# Processing file 374/809: output_1793_fir_0277.pdf
# Processing file 375/809: output_1793_fir_0281.pdf
# Processing file 376/809: output_1793_fir_0282.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 377/809: output_1793_fir_0283.pdf
# Processing file 378/809: output_1793_fir_0284.pdf
# Processing file 379/809: output_1793_fir_0287.pdf
# Processing file 380/809: output_1793_fir_0288.pdf
# Processing file 381/809: output_1793_fir_0290.pdf
# Processing file 382/809: output_1793_fir_0293.pdf
# Processing file 383/809: output_1793_fir_0298.pdf
# Processing file 384/809: output_1793_fir_0300.pdf
# Processing file 385/809: output_1793_fir_0303.pdf
# Processing file 386/809: output_1793_fir_0310.pdf
# Processing file 387/809: output_1793_fir_0311.pdf
# Processing file 388/809: output_1793_fir_0312.pdf
# Processing file 389/809: output_1793_fir_0313.pdf
# Processing file 390/809: output_1793_fir_0314.pdf
# Processing file 391/809: output_1793_fir_0315.pdf
# Processing file 392/809: output_1793_fir_0316.pdf
# Processing file 393/809: output_1793_fir_0319.pdf
# Processing file 394/809: output_1793_fir_0320.pdf
# Processing file 395/809: output_1793_fir_0321.pdf
# Processing file 396/809: output_1793_fir_0323.pdf
# Processing file 397/809: output_1793_fir_0324.pdf
# Processing file 398/809: output_1793_fir_0326.pdf
# Processing file 399/809: output_1793_fir_0327.pdf
# Processing file 400/809: output_1793_fir_0328.pdf
# Processing file 401/809: output_1793_fir_0332.pdf
# Processing file 402/809: output_1793_fir_0333.pdf
# Processing file 403/809: output_1793_fir_0340.pdf
# Processing file 404/809: output_1793_fir_0341.pdf
# Processing file 405/809: output_1793_fir_0342.pdf
# Processing file 406/809: output_1793_fir_0343.pdf
# Processing file 407/809: output_1793_fir_0344.pdf
# Processing file 408/809: output_1793_fir_0345.pdf
# Processing file 409/809: output_1793_fir_0346.pdf
# Processing file 410/809: output_1793_fir_0347.pdf
# Processing file 411/809: output_1793_fir_0348.pdf
# Processing file 412/809: output_1793_fir_0349.pdf
# Processing file 413/809: output_1793_fir_0350.pdf
# Processing file 414/809: output_1793_fir_0351.pdf
# Processing file 415/809: output_1793_fir_0352.pdf
# Processing file 416/809: output_1793_fir_0353.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 417/809: output_1793_fir_0354.pdf
# Processing file 418/809: output_1793_fir_0357.pdf
# Processing file 419/809: output_1793_fir_0358.pdf
# Processing file 420/809: output_1793_fir_0360.pdf
# Processing file 421/809: output_1793_fir_0361.pdf
# Processing file 422/809: output_1793_fir_0365.pdf
# Processing file 423/809: output_1793_fir_0366.pdf
# Processing file 424/809: output_1793_fir_0367.pdf
# Processing file 425/809: output_1793_fir_0368.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 426/809: output_1793_fir_0369.pdf
# Processing file 427/809: output_1793_fir_0371.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 428/809: output_1793_fir_0372.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 429/809: output_1793_fir_0373.pdf
# Processing file 430/809: output_1793_fir_0374.pdf
# Processing file 431/809: output_1793_fir_0375.pdf
# Processing file 432/809: output_1793_fir_0376.pdf
# Processing file 433/809: output_1793_fir_0377.pdf
# Processing file 434/809: output_1793_fir_0378.pdf
# Processing file 435/809: output_1793_fir_0380.pdf
# Processing file 436/809: output_1793_fir_0381.pdf
# Processing file 437/809: output_1793_fir_0382.pdf
# Processing file 438/809: output_1793_fir_0383.pdf
# Processing file 439/809: output_1793_fir_0384.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 440/809: output_1793_fir_0386.pdf
# Processing file 441/809: output_1794_fir_0069.pdf
# Processing file 442/809: output_1794_fir_0081.pdf
# Processing file 443/809: output_1794_fir_0147.pdf
# Processing file 444/809: output_1794_fir_0204.pdf
# Processing file 445/809: output_1794_fir_0221.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 446/809: output_1794_fir_0222.pdf
# Processing file 447/809: output_1794_fir_0227.pdf
# Processing file 448/809: output_1794_fir_0332.pdf
# Processing file 449/809: output_1794_fir_0350.pdf
# Processing file 450/809: output_1794_fir_0352.pdf
# Processing file 451/809: output_1794_fir_0353.pdf
# Processing file 452/809: output_1794_fir_0361.pdf
# Processing file 453/809: output_1794_fir_0377.pdf
# Processing file 454/809: output_1794_fir_0378.pdf
# Processing file 455/809: output_1794_fir_0386.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 456/809: output_1795_fir_0006.pdf
# Processing file 457/809: output_1795_fir_0016.pdf
# Processing file 458/809: output_1795_fir_0145.pdf
# Processing file 459/809: output_1795_fir_0172.pdf
# Processing file 460/809: output_1795_fir_0245.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 461/809: output_1795_fir_0319.pdf
# Processing file 462/809: output_1795_fir_0419.pdf
# Processing file 463/809: output_1795_fir_0421.pdf
# Processing file 464/809: output_1795_fir_0427.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 465/809: output_1795_fir_0440.pdf
# Processing file 466/809: output_1795_fir_0453.pdf
# Processing file 467/809: output_1795_fir_0455.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 468/809: output_1795_fir_0461.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 469/809: output_1795_fir_0464.pdf
# Processing file 470/809: output_1795_fir_0465.pdf
# Processing file 471/809: output_1795_fir_0467.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 472/809: output_1795_fir_0470.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 473/809: output_1795_fir_0472.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 474/809: output_1795_fir_0473.pdf
# Processing file 475/809: output_1895_fir_0037.pdf
# Processing file 476/809: output_1895_fir_0112.pdf
# Processing file 477/809: output_1895_fir_0173.pdf
# Processing file 478/809: output_1895_fir_0218.pdf
# Processing file 479/809: output_1895_fir_0253.pdf
# Processing file 480/809: output_1895_fir_0283.pdf
# Processing file 481/809: output_1895_fir_0325.pdf
# Processing file 482/809: output_1895_fir_0331.pdf
# Processing file 483/809: output_1895_fir_0347.pdf
# Processing file 484/809: output_1895_fir_0348.pdf
# Processing file 485/809: output_1895_fir_0351.pdf
# Processing file 486/809: output_1895_fir_0353.pdf
# Processing file 487/809: output_1895_fir_0354.pdf
# Processing file 488/809: output_1895_fir_0355.pdf
# Processing file 489/809: output_1895_fir_0359.pdf
# Processing file 490/809: output_1895_fir_0360.pdf
# Processing file 491/809: output_1895_fir_0361.pdf
# Processing file 492/809: output_1895_fir_0362.pdf
# Processing file 493/809: output_1895_fir_0363.pdf
# Processing file 494/809: output_1895_fir_0364.pdf
# Processing file 495/809: output_1895_fir_0365.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 496/809: output_1895_fir_0368.pdf
# Processing file 497/809: output_1895_fir_0369.pdf
# Processing file 498/809: output_1895_fir_0370.pdf
# Processing file 499/809: output_1895_fir_0371.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 500/809: output_1895_fir_0372.pdf
# Processing file 501/809: output_1895_fir_0373.pdf
# Processing file 502/809: output_1896_fir_0160.pdf
# Processing file 503/809: output_1896_fir_0188.pdf
# Processing file 504/809: output_1896_fir_0195.pdf
# Processing file 505/809: output_1896_fir_0214.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 506/809: output_1896_fir_0216.pdf
# Processing file 507/809: output_1896_fir_0229.pdf
# Processing file 508/809: output_1896_fir_0240.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 509/809: output_1896_fir_0249.pdf
# Processing file 510/809: output_1896_fir_0253.pdf
# Processing file 511/809: output_1896_fir_0264.pdf
# Processing file 512/809: output_1896_fir_0265.pdf
# Processing file 513/809: output_1896_fir_0269.pdf
# Processing file 514/809: output_1896_fir_0273.pdf
# Processing file 515/809: output_1896_fir_0279.pdf
# Processing file 516/809: output_1896_fir_0280.pdf
# Processing file 517/809: output_1896_fir_0291.pdf
# Processing file 518/809: output_1896_fir_0296.pdf
# Processing file 519/809: output_1896_fir_0298.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 520/809: output_1896_fir_0308.pdf
# Processing file 521/809: output_1896_fir_0323.pdf
# Processing file 522/809: output_1896_fir_0326.pdf
# Processing file 523/809: output_1896_fir_0327.pdf
# Processing file 524/809: output_1896_fir_0331.pdf
# Processing file 525/809: output_1896_fir_0342.pdf
# Processing file 526/809: output_1896_fir_0347.pdf
# Processing file 527/809: output_1896_fir_0357.pdf
# Processing file 528/809: output_1896_fir_0358.pdf
# Processing file 529/809: output_1896_fir_0359.pdf
# Processing file 530/809: output_1896_fir_0360.pdf
# Processing file 531/809: output_1896_fir_0362.pdf
# Processing file 532/809: output_1896_fir_0363.pdf
# Processing file 533/809: output_1896_fir_0365.pdf
# Processing file 534/809: output_1896_fir_0366.pdf
# Processing file 535/809: output_1896_fir_0367.pdf
# Processing file 536/809: output_1896_fir_0368.pdf
# Processing file 537/809: output_1896_fir_0369.pdf
# Processing file 538/809: output_1896_fir_0370.pdf
# Processing file 539/809: output_1896_fir_0374.pdf
# Processing file 540/809: output_1896_fir_0375.pdf
# Processing file 541/809: output_1896_fir_0376.pdf
# Processing file 542/809: output_1896_fir_0377.pdf
# Processing file 543/809: output_1896_fir_0378.pdf
# Processing file 544/809: output_1898_fir_0001.pdf
# Processing file 545/809: output_1898_fir_0020.pdf
# Processing file 546/809: output_1898_fir_0022.pdf
# Processing file 547/809: output_1898_fir_0041.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 548/809: output_1898_fir_0043.pdf
# Processing file 549/809: output_1898_fir_0053.pdf
# Processing file 550/809: output_1898_fir_0069.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 551/809: output_1898_fir_0071.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 552/809: output_1898_fir_0072.pdf
# Processing file 553/809: output_1898_fir_0077.pdf
# Processing file 554/809: output_1898_fir_0080.pdf
# Processing file 555/809: output_1898_fir_0090.pdf
# Processing file 556/809: output_1898_fir_0096.pdf
# Processing file 557/809: output_1898_fir_0098.pdf
# Processing file 558/809: output_1898_fir_0100.pdf
# Processing file 559/809: output_1898_fir_0104.pdf
# Processing file 560/809: output_1898_fir_0114.pdf
# Processing file 561/809: output_1898_fir_0115.pdf
# Processing file 562/809: output_1898_fir_0117.pdf
# Processing file 563/809: output_1898_fir_0120.pdf
# Processing file 564/809: output_1898_fir_0122.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 565/809: output_1898_fir_0124.pdf
# Processing file 566/809: output_1898_fir_0125.pdf
# Processing file 567/809: output_1898_fir_0127.pdf
# Processing file 568/809: output_1898_fir_0128.pdf
# Processing file 569/809: output_1898_fir_0129.pdf
# Processing file 570/809: output_1898_fir_0130.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 571/809: output_1898_fir_0131.pdf
# Processing file 572/809: output_1898_fir_0132.pdf
# Processing file 573/809: output_1898_fir_0133.pdf
# Processing file 574/809: output_1898_fir_0134.pdf
# Processing file 575/809: output_1898_fir_0135.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 576/809: output_1898_fir_0136.pdf
# Processing file 577/809: output_1898_fir_0137.pdf
# Processing file 578/809: output_1898_fir_0138.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 579/809: output_1898_fir_0139.pdf
# Processing file 580/809: output_1898_fir_0140.pdf
# Processing file 581/809: output_1898_fir_0141.pdf
# Processing file 582/809: output_1898_fir_0142.pdf
# Processing file 583/809: output_1898_fir_0143.pdf
# Processing file 584/809: output_1898_fir_0144.pdf
# Processing file 585/809: output_1898_fir_0145.pdf
# Processing file 586/809: output_1898_fir_0146.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 587/809: output_1898_fir_0147.pdf
# Processing file 588/809: output_1898_fir_0148.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 589/809: output_1898_fir_0149.pdf
# Processing file 590/809: output_1898_fir_0150.pdf
# Processing file 591/809: output_1898_fir_0151.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 592/809: output_1898_fir_0152.pdf
# Processing file 593/809: output_1898_fir_0153.pdf
# Processing file 594/809: output_1898_fir_0154.pdf
# Processing file 595/809: output_1898_fir_0155.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 596/809: output_1898_fir_0156.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 597/809: output_1898_fir_0157.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 598/809: output_1898_fir_0159.pdf
# Processing file 599/809: output_1898_fir_0160.pdf
# Processing file 600/809: output_1898_fir_0161.pdf
# Processing file 601/809: output_1898_fir_0162.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 602/809: output_1898_fir_0163.pdf
# Processing file 603/809: output_1898_fir_0164.pdf
# Processing file 604/809: output_1899_fir_0003.pdf
# Processing file 605/809: output_1899_fir_0011.pdf
# Processing file 606/809: output_1899_fir_0030.pdf
# Processing file 607/809: output_1899_fir_0034.pdf
# Processing file 608/809: output_1899_fir_0040.pdf
# Processing file 609/809: output_1899_fir_0043.pdf
# Processing file 610/809: output_1899_fir_0047.pdf
# Processing file 611/809: output_1899_fir_0065.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 612/809: output_1899_fir_0105.pdf
# Processing file 613/809: output_1899_fir_0108.pdf
# Processing file 614/809: output_1899_fir_0124.pdf
# Processing file 615/809: output_1899_fir_0128.pdf
# Processing file 616/809: output_1899_fir_0147.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 617/809: output_1899_fir_0149.pdf
# Processing file 618/809: output_1899_fir_0151.pdf
# Processing file 619/809: output_1899_fir_0154.pdf
# Processing file 620/809: output_1899_fir_0176.pdf
# Processing file 621/809: output_1899_fir_0179.pdf
# Processing file 622/809: output_1899_fir_0180.pdf
# Processing file 623/809: output_1899_fir_0188.pdf
# Processing file 624/809: output_1899_fir_0190.pdf
# Processing file 625/809: output_1899_fir_0192.pdf
# Processing file 626/809: output_1899_fir_0226.pdf
# Processing file 627/809: output_1899_fir_0229.pdf
# Processing file 628/809: output_1899_fir_0230.pdf
# Processing file 629/809: output_1899_fir_0239.pdf
# Processing file 630/809: output_1899_fir_0241.pdf
# Processing file 631/809: output_1899_fir_0245.pdf
# Processing file 632/809: output_1899_fir_0250.pdf
# Processing file 633/809: output_1899_fir_0251.pdf
# Processing file 634/809: output_1899_fir_0256.pdf
# Processing file 635/809: output_1899_fir_0258.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 636/809: output_1899_fir_0259.pdf
# Processing file 637/809: output_1899_fir_0265.pdf
# Processing file 638/809: output_1899_fir_0266.pdf
# Processing file 639/809: output_1899_fir_0267.pdf
# Processing file 640/809: output_1899_fir_0268.pdf
# Processing file 641/809: output_1899_fir_0270.pdf
# Processing file 642/809: output_1899_fir_0271.pdf
# Processing file 643/809: output_1899_fir_0272.pdf
# Processing file 644/809: output_1899_fir_0274.pdf
# Processing file 645/809: output_1899_fir_0275.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 646/809: output_1899_fir_0276.pdf
# Processing file 647/809: output_1899_fir_0277.pdf
# Processing file 648/809: output_2001_fir_0005.pdf
# Processing file 649/809: output_2001_fir_0023.pdf
# Processing file 650/809: output_2001_fir_0069.pdf
# Processing file 651/809: output_2001_fir_0090.pdf
# Processing file 652/809: output_2001_fir_0136.pdf
# Processing file 653/809: output_2001_fir_0149.pdf
# Processing file 654/809: output_2001_fir_0150.pdf
# Processing file 655/809: output_2001_fir_0153.pdf
# Processing file 656/809: output_2001_fir_0155.pdf
# Processing file 657/809: output_2001_fir_0156.pdf
# Processing file 658/809: output_2001_fir_0158.pdf
# Processing file 659/809: output_2001_fir_0162.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 660/809: output_2001_fir_0163.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 661/809: output_2001_fir_0164.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 662/809: output_2001_fir_0165.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 663/809: output_2001_fir_0166.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 664/809: output_2001_fir_0167.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 665/809: output_2001_fir_0168.pdf
# Processing file 666/809: output_2001_fir_0169.pdf
# Processing file 667/809: output_2001_fir_0170.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 668/809: output_2001_fir_0172.pdf
# Processing file 669/809: output_2001_fir_0173.pdf
# Processing file 670/809: output_2001_fir_0174.pdf
# Processing file 671/809: output_2001_fir_0175.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 672/809: output_2001_fir_0176.pdf
# Processing file 673/809: output_2001_fir_0177.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 674/809: output_2005_fir_0022.pdf
# Processing file 675/809: output_2005_fir_0266.pdf
# Processing file 676/809: output_2006_fir_0029.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 677/809: output_2006_fir_0043.pdf
# Processing file 678/809: output_2006_fir_0045.pdf
# Processing file 679/809: output_2006_fir_0056.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 680/809: output_2006_fir_0091.pdf
# Processing file 681/809: output_2006_fir_0095.pdf
# Processing file 682/809: output_2006_fir_0125.pdf
# Processing file 683/809: output_2006_fir_0160.pdf
# Processing file 684/809: output_2006_fir_0164.pdf
# Processing file 685/809: output_2006_fir_0167.pdf
# Processing file 686/809: output_2006_fir_0174.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 687/809: output_2006_fir_0176.pdf
# Processing file 688/809: output_2006_fir_0187.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 689/809: output_2006_fir_0203.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 690/809: output_2006_fir_0236.pdf
# Processing file 691/809: output_2006_fir_0259.pdf
# Processing file 692/809: output_2006_fir_0265.pdf
# Processing file 693/809: output_2006_fir_0272.pdf
# Processing file 694/809: output_2006_fir_0279.pdf
# Processing file 695/809: output_2006_fir_0299.pdf
# Processing file 696/809: output_2006_fir_0304.pdf
# Processing file 697/809: output_2006_fir_0308.pdf
# Processing file 698/809: output_2006_fir_0314.pdf
# Processing file 699/809: output_2006_fir_0321.pdf
# Processing file 700/809: output_2006_fir_0329.pdf
# Processing file 701/809: output_2006_fir_0330.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 702/809: output_2006_fir_0332.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 703/809: output_2006_fir_0336.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 704/809: output_2006_fir_0340.pdf
# Processing file 705/809: output_2006_fir_0343.pdf
# Processing file 706/809: output_2006_fir_0352.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 707/809: output_2006_fir_0353.pdf
# Processing file 708/809: output_2006_fir_0358.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 709/809: output_2006_fir_0359.pdf
# Processing file 710/809: output_2006_fir_0360.pdf
# Processing file 711/809: output_2006_fir_0364.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 712/809: output_2006_fir_0370.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 713/809: output_2006_fir_0371.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 714/809: output_2006_fir_0374.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 715/809: output_2006_fir_0378.pdf
# Processing file 716/809: output_2006_fir_0379.pdf
# Processing file 717/809: output_2006_fir_0385.pdf
# Processing file 718/809: output_2006_fir_0386.pdf
# Processing file 719/809: output_2006_fir_0387.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 720/809: output_2006_fir_0388.pdf
# Processing file 721/809: output_2006_fir_0390.pdf
# Processing file 722/809: output_2006_fir_0391.pdf
# Processing file 723/809: output_2006_fir_0392.pdf
# Processing file 724/809: output_2006_fir_0393.pdf
# Processing file 725/809: output_2006_fir_0394.pdf
# Processing file 726/809: output_2006_fir_0395.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 727/809: output_2006_fir_0399.pdf
# Processing file 728/809: output_2006_fir_0400.pdf
# Processing file 729/809: output_2006_fir_0403.pdf
# Processing file 730/809: output_2006_fir_0404.pdf
# Processing file 731/809: output_2006_fir_0405.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 732/809: output_2006_fir_0407.pdf
# Processing file 733/809: output_2006_fir_0408.pdf
# Processing file 734/809: output_2006_fir_0409.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 735/809: output_2006_fir_0410.pdf
# Processing file 736/809: output_2006_fir_0412.pdf
# Processing file 737/809: output_2006_fir_0414.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 738/809: output_2006_fir_0415.pdf
# Processing file 739/809: output_2006_fir_0416.pdf
# Processing file 740/809: output_2006_fir_0417.pdf
# Processing file 741/809: output_2006_fir_0418.pdf
# Processing file 742/809: output_2006_fir_0421.pdf
# Processing file 743/809: output_2006_fir_0422.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 744/809: output_2006_fir_0424.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 745/809: output_2006_fir_0426.pdf
# Processing file 746/809: output_2006_fir_0430.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 747/809: output_2006_fir_0431.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 748/809: output_2006_fir_0433.pdf
# Processing file 749/809: output_2006_fir_0434.pdf
# Processing file 750/809: output_2006_fir_0435.pdf
# Processing file 751/809: output_2006_fir_0436.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 752/809: output_2006_fir_0437.pdf
# Processing file 753/809: output_2006_fir_0438.pdf
# Processing file 754/809: output_2006_fir_0439.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 755/809: output_2006_fir_0440.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 756/809: output_2006_fir_0441.pdf
# Processing file 757/809: output_2006_fir_0442.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 758/809: output_2006_fir_0443.pdf
# Processing file 759/809: output_2006_fir_0444.pdf
# Processing file 760/809: output_2006_fir_0445.pdf
# Processing file 761/809: output_2006_fir_0447.pdf
# Processing file 762/809: output_2006_fir_0449.pdf
# Processing file 763/809: output_2006_fir_0450.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 764/809: output_2123_fir_0033.pdf
# Processing file 765/809: output_2201_fir_0040.pdf
# Processing file 766/809: output_2201_fir_0088.pdf
# Processing file 767/809: output_2201_fir_0114.pdf
# Processing file 768/809: output_2201_fir_0115.pdf
# Processing file 769/809: output_2201_fir_0118.pdf
# Processing file 770/809: output_2201_fir_0119.pdf
# Processing file 771/809: output_2201_fir_0120.pdf
# Processing file 772/809: output_2201_fir_0123.pdf
# Processing file 773/809: output_2318_fir_0078.pdf
# Processing file 774/809: output_2318_fir_0131.pdf
# Processing file 775/809: output_2318_fir_0132.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 776/809: output_2318_fir_0153.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 777/809: output_2318_fir_0168.pdf
# Processing file 778/809: output_2318_fir_0179.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 779/809: output_2318_fir_0198.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 780/809: output_2318_fir_0207.pdf
# Processing file 781/809: output_2318_fir_0219.pdf
# Processing file 782/809: output_2319_fir_0083.pdf
# Processing file 783/809: output_2319_fir_0086.pdf
# Processing file 784/809: output_2319_fir_0169.pdf
# Processing file 785/809: output_2319_fir_0175.pdf
# Processing file 786/809: output_2319_fir_0176.pdf
# Processing file 787/809: output_2319_fir_0177.pdf
# Processing file 788/809: output_2320_fir_0052.pdf
# Processing file 789/809: output_2320_fir_0058.pdf
# Processing file 790/809: output_2320_fir_0076.pdf
# Processing file 791/809: output_2320_fir_0080.pdf
# Processing file 792/809: output_2320_fir_0132.pdf
# Processing file 793/809: output_2320_fir_0147.pdf
# Processing file 794/809: output_2320_fir_0148.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 795/809: output_2320_fir_0167.pdf
# Processing file 796/809: output_2320_fir_0181.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 797/809: output_2320_fir_0183.pdf
# Processing file 798/809: output_2320_fir_0184.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 799/809: output_2320_fir_0185.pdf
# Processing file 800/809: output_2320_fir_0186.pdf
# Processing file 801/809: output_2320_fir_0187.pdf
# Processing file 802/809: output_2321_fir_0027.pdf
# Processing file 803/809: output_2321_fir_0145.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 804/809: output_2321_fir_0297.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 805/809: output_2321_fir_0298.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 806/809: output_2321_fir_0300.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 807/809: output_2321_fir_0302.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 808/809: output_2321_fir_0304.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
# Processing file 809/809: output_2321_fir_0305.pdf
# Error processing PDF: No /Root object! - Is this really a PDF?
#
# Processing Summary:
# Total files processed: 809
# Successfully processed: 809
# Failed to process: 0
#
# Dataset Statistics:
# Total rows: 809
# Total columns: 29
#
# Unique values in key columns:
# district: 4 unique values
# police_station: 47 unique values
# crime_no: 360 unique values

# %%
import pdfplumber
import re
from dataclasses import dataclass
from typing import Optional, List, Dict, Any
from datetime import datetime

@dataclass
class PropertyDetails:
    """Data class for stolen/involved property information"""
    sl_no: int
    property_type: Optional[str] = None
    item_description: Dict[str, Any] = None  
    estimated_value: Optional[float] = None

@dataclass
class VictimDetails:
    """Data class for victim information"""
    sl_no: int
    name: Optional[str] = None
    address: Optional[str] = None
    injury_type: Optional[str] = None
    sex: Optional[str] = None
    age: Optional[int] = None
    occupation: Optional[str] = None

@dataclass
class AccusedDetails:
    """Data class for accused person information"""
    sl_no: int
    name: Optional[str] = None
    father_name: Optional[str] = None  # Details after the '/'
    person_type: Optional[str] = None
    sex: Optional[str] = None
    age: Optional[int] = None
    occupation: Optional[str] = None

@dataclass
class FIRData:
    """Data class to store extracted FIR information"""
    district: Optional[str] = None
    circle_subdivision: Optional[str] = None
    police_station: Optional[str] = None
    crime_no: Optional[str] = None
    fir_date: Optional[datetime] = None
    act_section: Optional[str] = None
    offense_date: Optional[datetime] = None
    offense_time_from: Optional[str] = None
    offense_time_to: Optional[str] = None
    location: Optional[str] = None
    distance_ps: Optional[str] = None
    complainant_name: Optional[str] = None
    complainant_age: Optional[int] = None
    complainant_religion: Optional[str] = None
    complainant_caste: Optional[str] = None
    complainant_occupation: Optional[str] = None
    phone_number: Optional[str] = None
    nationality: Optional[str] = None
    sex: Optional[str] = None
    complainant_address: Optional[str] = None
    victim_details: List[VictimDetails] = None
    property_details: List[PropertyDetails] = None
    total_property_value: Optional[float] = None
    accused_details: List[AccusedDetails] = None

    def __post_init__(self):
        if self.victim_details is None:
            self.victim_details = []
        if self.property_details is None:
            self.property_details = []
        if self.accused_details is None:
            self.accused_details = []

    def print_details(self):
        """Print all FIR details in a formatted manner"""
        print("\n=== FIR Details ===")
        print(f"District: {self.district}")
        print(f"Circle/Sub-Division: {self.circle_subdivision}")
        print(f"Police Station: {self.police_station}")
        print(f"Crime Number: {self.crime_no}")
        print(f"FIR Date: {self.fir_date.strftime('%d/%m/%Y') if self.fir_date else None}")
        print(f"Act & Section: {self.act_section}")
        
        print("\nOffense Details:")
        print(f"Date: {self.offense_date.strftime('%d/%m/%Y') if self.offense_date else None}")
        print(f"Time: {self.offense_time_from} to {self.offense_time_to}")
        print(f"Location: {self.location}")
        print(f"Distance from Police Station: {self.distance_ps}")

        print("\nComplainant Details:")
        print(f"Name: {self.complainant_name}")
        print(f"Age: {self.complainant_age}")
        print(f"Religion: {self.complainant_religion}")
        print(f"Caste: {self.complainant_caste}")
        print(f"Occupation: {self.complainant_occupation}")
        print(f"Phone: {self.phone_number}")
        print(f"Nationality: {self.nationality}")
        print(f"Sex: {self.sex}")
        print(f"Address: {self.complainant_address}")
        
        print("\nProperty Details:")
        for prop in self.property_details:
            print(f"- Type: {prop.property_type}")
            if prop.item_description:
                print("  Item Description:")
                for key, value in prop.item_description.items():
                    print(f"    {key}: {value}")
            print(f"  Estimated Value: {f'Rs. {prop.estimated_value:,.2f}' if prop.estimated_value else None}")
        print(f"Total Property Value: {f'Rs. {self.total_property_value:,.2f}' if self.total_property_value else None}")

        print("\nAccused Details:")
        for accused in self.accused_details:
            print(f"- Accused {accused.sl_no}:")
            print(f"  Name: {accused.name}")
            print(f"  Father/Details: {accused.father_name}")
            print(f"  Person Type: {accused.person_type}")
            print(f"  Sex: {accused.sex}")
            print(f"  Age: {accused.age}")
            print(f"  Occupation: {accused.occupation}")
        print("==================\n")

def safe_search(pattern: str, text: str, group_num: int = 1) -> Optional[str]:
    """Helper function to safely perform regex search and return the matched group or None."""
    try:
        match = re.search(pattern, text)
        return match.group(group_num).strip() if match else None
    except (AttributeError, IndexError):
        return None

def safe_parse_date(date_str: Optional[str], format_str: str = "%d/%m/%Y") -> Optional[datetime]:
    """Safely parse date string to datetime object."""
    if not date_str:
        return None
    try:
        return datetime.strptime(date_str, format_str)
    except ValueError:
        return None

def safe_parse_int(value: Optional[str]) -> Optional[int]:
    """Safely parse string to integer."""
    if not value:
        return None
    try:
        return int(re.sub(r'[^\d]', '', value))
    except ValueError:
        return None

def safe_parse_float(amount_str: Optional[str]) -> Optional[float]:
    """Safely parse string to float, handling commas in numbers."""
    if not amount_str:
        return None
    try:
        return float(amount_str.replace(',', ''))
    except ValueError:
        return None

def extract_property_details(text: str) -> List[PropertyDetails]:
    properties = []
    
    # Find all property entries using registration numbers as anchor points
    reg_numbers = re.finditer(r"Reg No:\s*(KA\d+[A-Z]+\d+)", text)
    reg_positions = [(m.group(1), m.start()) for m in reg_numbers]
    
    if not reg_positions:
        return properties
    
    for idx, (reg_no, start_pos) in enumerate(reg_positions):
        end_pos = reg_positions[idx + 1][1] if idx < len(reg_positions) - 1 else len(text)
        property_text = text[start_pos:end_pos]
        
        item_desc = {
            "reg_no": reg_no,
            "make": safe_search(r"Make:?\s*([^\n]+?)(?=\s*Model|$)", property_text),
            "model": safe_search(r"Model:?\s*([^\n]+?)(?=\s*Engine|$)", property_text),
            "engine_no": safe_search(r"Engine No:?\s*([^\n]+?)(?=\s*Chassis|$)", property_text),
            "chassis_no": safe_search(r"Chassis No:?\s*([^\n]+?)(?=\n|$)", property_text)
        }
        
        value_str = safe_search(r"Estimated Value\s*\([^)]*\)\s*\n*\s*([\d,]+)", text)
        estimated_value = safe_parse_float(value_str) or 0
        
        properties.append(PropertyDetails(
            sl_no=idx + 1,
            property_type="Automobile",
            item_description=item_desc,
            estimated_value=estimated_value
        ))
    
    return properties

def extract_accused_details(text: str) -> List[AccusedDetails]:
    """Extract accused details from the FIR text"""
    accused_list = []
    
    # First find all accused entries
    accused_matches = list(re.finditer(r'(\w+)\s*\(A(\d+)\)\s*/\s*([^\n]+)', text))
    
    for idx, match in enumerate(accused_matches):
        name = match.group(1).strip()
        sl_no = int(match.group(2))
        first_line = match.group(3).strip()
        
        next_pos = accused_matches[idx + 1].start() if idx + 1 < len(accused_matches) else len(text)
        full_text = text[match.start():next_pos].strip()
        
        lines = full_text.split('\n')
        
        main_details = first_line
        father_details = main_details.split("Accused")[0].strip()
        
        person_type = safe_search(r"Accused\s+(\w+)", main_details)
        sex = safe_search(r"(?:Adult|Child|Common|Common man)\s+(\w+)", main_details)
        age_str = safe_search(r"(?:Male|Female)\s+(\d+)", main_details)
        age = safe_parse_int(age_str)
        occupation = safe_search(r"(?:Male|Female)\s+\d+\s+(.+?)$", main_details)
        
        additional_lines = []
        for line in lines[1:]: 
            line = line.strip()
            if line and not re.search(r'\(A\d+\)', line):  
                additional_lines.append(line)
     
        full_details = father_details
        if additional_lines:
            full_details += ", " + " ".join(additional_lines)

        if "7. Details of Victims" in full_details:
            full_details = full_details.split("7. Details of Victims")[0].strip()
        
        accused_list.append(AccusedDetails(
            sl_no=sl_no,
            name=name,
            father_name=full_details,
            person_type=person_type,
            sex=sex,
            age=age,
            occupation=occupation
        ))
    
    return accused_list
        

def extract_fir_data(pdf_path: str) -> FIRData:
    """Extract relevant information from FIR PDF document with error handling"""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            text = " ".join([page.extract_text() for page in pdf.pages])
            
            # Basic FIR details
            district = safe_search(r"District\s*:\s*([^:\n]+?)(?=\s+Circle/Sub Division|$)", text)
            circle = safe_search(r"Circle/Sub Division\s*:\s*([^:\n]+?)(?=\s+PS|$)", text)
            ps = safe_search(r"PS\s*:\s*([^:\n]+?)(?=\s*$|\s*\n)", text)
            crime_no = safe_search(r"Crime No\s*:\s*([^:\n]+?)(?=\s+FIR Date|$)", text)
            
            # Dates and times
            fir_date_str = safe_search(r"FIR Date\s*:\s*(\d{2}/\d{1,2}/\d{4})", text)
            fir_date = safe_parse_date(fir_date_str)
            
            offense_date_str = safe_search(r"From Date\s*:\s*(\d{2}/\d{2}/\d{4})", text)
            offense_date = safe_parse_date(offense_date_str)
            
            time_from = safe_search(r"From Time\s*:\s*(\d{2}:\d{2}:\d{2})", text)
            time_to = safe_search(r"To Time\s*:\s*(\d{2}:\d{2}:\d{2})", text)
            
            # Location and distance
            location = re.search(r"Place of occurence with full address\s*(.*?)(?=\(b\))", text, re.DOTALL).group(1).strip()
            distance_match = re.search(r"(?:(Tow(?:ards|ords)\s+\w+)\s*([\d\.]+)\s*(K\s*M|KM|Km|KMs|Meters|M)?)|(?:([\d\.]+)\s*(K\s*M|KM|Km|KMs|Meters|M)?\s*(Tow(?:ards|ords)\s+\w+))", text, re.IGNORECASE)
            
            distance_ps = None
            if distance_match:
                direction = (distance_match.group(1) or distance_match.group(6) or "").strip()
                distance_value = (distance_match.group(2) or distance_match.group(4) or "").strip()
                distance_unit = (distance_match.group(3) or distance_match.group(5) or "").strip()
                if direction and distance_value:
                    distance_ps = f"{direction}, {distance_value} {distance_unit}".strip()
            
            # Complainant details
            complainant_name = safe_search(r"Name\s*:\s*([^:\n]+?)(?=\s+Father)", text)
            complainant_age_str = safe_search(r"Age\s*:\s*(\d+)", text)
            complainant_age = safe_parse_int(complainant_age_str)
            complainant_religion = safe_search(r"Religion\s*:\s*([^:\n]+?)(?=\s*(?:\([e-z]\)|$))", text)
            complainant_caste = safe_search(r"Caste\s*:\s*([^:\n]+?)(?=\s*(?:\([f-z]\)|$))", text)
            complainant_occupation = safe_search(r"Occupation\s*:\s*([^\n]*)", text)
            phone_number = safe_search(r"Phone No\.\s*:\s*(\d+)", text)
            nationality = safe_search(r"Nationality\s*:\s*([^:\n]+?)(?=\s|$)", text)
            sex = safe_search(r"Sex:\s*([^:\n]+?)(?=\s|$)", text)
            
            # Address extraction
            address_match = safe_search(r"\(k\)\s*Address\s*:\s*([\s\S]*?)(?=\([m-z]\)|Whether complainant|$)", text)
            complainant_address = None
            if address_match:
                address_text = address_match
                sex_pattern = r"\(l\)\s*Sex:\s*[A-Za-z]+\s*"
                address_text = re.sub(sex_pattern, "", address_text)
                complainant_address = " ".join(line.strip() for line in address_text.split('\n') if line.strip())
            
            # Property details
            property_details = extract_property_details(text)
            
            # Total value
            total_value_str = safe_search(r"Total Value[^:]*:?\s*(?:Rs\.?)?\s*(\d+,?\d*)", text)
            total_property_value = safe_parse_float(total_value_str)
            
            act_section = safe_search(r"Act & Section\s*:\s*([^:\n]+)", text)

            accused_details = extract_accused_details(text)
            
            return FIRData(
                district=district,
                circle_subdivision=circle,
                police_station=ps,
                crime_no=crime_no,
                fir_date=fir_date,
                act_section=act_section,
                offense_date=offense_date,
                offense_time_from=time_from,
                offense_time_to=time_to,
                location=location,
                distance_ps=distance_ps,
                complainant_name=complainant_name,
                complainant_age=complainant_age,
                complainant_religion=complainant_religion,
                complainant_caste=complainant_caste,
                complainant_occupation=complainant_occupation,
                phone_number=phone_number,
                nationality=nationality,
                sex=sex,
                complainant_address=complainant_address,
                victim_details=[],
                property_details=property_details,
                total_property_value=total_property_value,
                accused_details=accused_details
            )
            
    except Exception as e:
        print(f"Error processing PDF: {str(e)}")
        return FIRData()  # Return empty FIRData object if processing fails

if __name__ == "__main__":
    # Process single FIR
    fir = extract_fir_data("G:/iisc/combined/fir_0009.pdf")
    fir.print_details()
# Out:
# === FIR Details ===
# District: Bengaluru City
# Circle/Sub-Division: South East Traffic Sub Divisio
# Police Station: Adugodi Traffic PS
# Crime Number: 0004/2024
# FIR Date: 09/02/2024
# Act & Section: IPC 1860 (U/s-283)
#
# Offense Details:
# Date: 09/02/2024
# Time: 15:55:00 to 16:05:00
# Location: 60 feet Road,, Koramangala,Bengaluru City , Karnataka, 560095
# Distance from Police Station: towards east, 1.5 KM
#
# Complainant Details:
# Name: Annappa Kattimani
# Age: 34
# Religion: Hindu
# Caste: BUDAGA JANGAMA
# Occupation: Police officer
# Phone: None
# Nationality: India
# Sex: Male
# Address: CPC12207,Adug odi Traffic Police station,Adugodi , Bengaluru City , Karnataka-56003 0
#
# Property Details:
# - Type: Automobile
#   Item Description:
#     reg_no: KA05JM5723
#     make: SCOOTER
#     model: -
#     engine_no: -
#     chassis_no: -
#   Estimated Value: Rs. 1.00
# Total Property Value: None
#
# Accused Details:
# - Accused 1:
#   Name: vikas
#   Father/Details: Janakaraj, ,#525, 3rd main, nanjappa reddy layout,koramnagalaBengaluru City, Karnataka
#   Person Type: Adult
#   Sex: Male
#   Age: 30
#   Occupation: None
# ==================
